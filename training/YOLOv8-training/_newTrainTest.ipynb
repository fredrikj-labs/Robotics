# %%
import os
import shutil
import random

SOURCE = r"C:\temp"
DEST = r"jetbot_groundview_dataset"
TRAIN_FRAC = 0.8  # 80% train, 20% val

img_dir = os.path.join(DEST, 'images')
lbl_dir = os.path.join(DEST, 'labels')

for split in ['train', 'val']:
    os.makedirs(os.path.join(img_dir, split), exist_ok=True)
    os.makedirs(os.path.join(lbl_dir, split), exist_ok=True)

# Gather all valid images (ignore debug, require matching txt)
all_images = []
for fname in os.listdir(SOURCE):
    if fname.endswith('.png') and 'debug' not in fname:
        base = fname[:-4]
        txt = base + '.txt'
        if os.path.exists(os.path.join(SOURCE, txt)):
            all_images.append(base)

random.shuffle(all_images)
split_idx = int(TRAIN_FRAC * len(all_images))
train_bases = all_images[:split_idx]
val_bases = all_images[split_idx:]

def copy_split(split_bases, split):
    for base in split_bases:
        img_src = os.path.join(SOURCE, base + '.png')
        lbl_src = os.path.join(SOURCE, base + '.txt')
        img_dst = os.path.join(img_dir, split, base + '.png')
        lbl_dst = os.path.join(lbl_dir, split, base + '.txt')
        shutil.copy2(img_src, img_dst)
        shutil.copy2(lbl_src, lbl_dst)

copy_split(train_bases, 'train')
copy_split(val_bases, 'val')

print(f"Dataset prepared in {DEST}. Train: {len(train_bases)} | Val: {len(val_bases)}")
# Out:
# Dataset prepared in jetbot_groundview_dataset. Train: 24000 | Val: 6000

# %%
import os
import random
import numpy as np
import torch
from ultralytics import YOLO

# ========== SETTINGS ==========
DATA_YAML = "jetbot_groundview_dataset/data.yaml"      # Path to your data.yaml
MODEL = "yolov8n.pt"                      # Or 'yolov8s.pt' for larger model
EPOCHS = 100
IMAGE_SIZE = 512
BATCH = 16                                 # Lower if OOM, higher if possible
DEVICE = 0                                # 'cpu' or 0 for first GPU
PROJECT = "runs/train"
NAME = "jetbot_groundview"
SEED = 42

# ========== SEED FOR REPRODUCIBILITY ==========
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# ========== TRAINING ==========
model = YOLO(MODEL)

results = model.train(
    data=DATA_YAML,
    epochs=EPOCHS,
    imgsz=IMAGE_SIZE,
    batch=BATCH,
    device=DEVICE,
    project=PROJECT,
    name=NAME,
    seed=SEED,
    workers=4,
    optimizer='SGD',        # Default (recommended)
    pretrained=True,
    val=True,
    save=True,
    plots=True,
    exist_ok=True,
    verbose=True
)

print("\n=== TRAINING FINISHED ===")
print("Results directory:", results.save_dir)
# Out:
# New https://pypi.org/project/ultralytics/8.3.145 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.141  Python-3.9.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=jetbot_groundview_dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=jetbot_groundview, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\train\jetbot_groundview, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 560.8238.7 MB/s, size: 173.8 KB)
# train: Scanning C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\labels.cache... 21000 images, 0 backgrounds, 10957 corrupt: 100%|██████████| 21000/21000 [00:00<?, ?it/s]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00000.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2901      1.5408]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00015.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4298]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00040.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1301]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00097.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7637      1.5819]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00107.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0943]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00112.png: ignoring corrupt image/label: negative label values [   -0.25488]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00117.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8494      1.5816]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00135.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2659      1.2257]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00143.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0725]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00153.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3755]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00163.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0304]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00181.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2562]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00210.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6861      1.9051]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00215.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3184      1.5653]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00220.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0092]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00230.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6998]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00233.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1821]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00242.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3395      1.5547]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00252.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3317      1.2277]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00257.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7563]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00267.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1707      1.4635]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00277.png: ignoring corrupt image/label: negative label values [   -0.15814]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00297.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4271]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00309.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5576]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00314.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2379]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00351.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2982]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00353.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.805      1.0364]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00358.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1915      1.1909      1.9338]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00363.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6018]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00373.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.9767]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00396.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3708]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00401.png: ignoring corrupt image/label: negative label values [  -0.011815]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00406.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5425]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00411.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6047]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00426.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6476]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00431.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2149]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00456.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8412      1.1696]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00461.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7062]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00476.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.548]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00481.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3212]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00500.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.9439]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00510.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.686      1.4453]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00525.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1565      1.1299]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00546.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0131      1.5107]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00566.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0825      1.3776]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00581.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1804]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00597.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4735]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00607.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0665       1.058      1.7402]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00617.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5493]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00642.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3355      1.3446]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00647.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0216      1.3847      1.6313]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00654.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0077]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00669.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2782]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00684.png: ignoring corrupt image/label: negative label values [  -0.069401]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00696.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0056      1.2953]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00706.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7919]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00716.png: ignoring corrupt image/label: negative label values [   -0.11712]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00737.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0222]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00789.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1644      1.3949      1.4225]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00813.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0893      1.4762]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00832.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3998      1.0999      1.5364]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00837.png: ignoring corrupt image/label: negative label values [  -0.032782]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00843.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.962]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00880.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8631      1.2794]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00900.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0602]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00914.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3505      1.4133]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00919.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.9536      1.1248      1.7683]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_00943.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2229]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01031.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6079]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01051.png: ignoring corrupt image/label: negative label values [   -0.22454]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01061.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8692]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01066.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0434      1.4381      1.5113       1.435]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01076.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2319]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01096.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5361      1.1816      1.0447]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01111.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2757]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01167.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5631]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01206.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0939]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01211.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3316]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01226.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7494      1.2748]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01231.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7461]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01236.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2536]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01241.png: ignoring corrupt image/label: negative label values [  -0.069618]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01256.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.401]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01260.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4135]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01280.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1527      1.0592      1.4427]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01285.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2838]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01295.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7744]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01311.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3663]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01321.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5335]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01336.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0426]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01343.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.9513]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01363.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5537]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01368.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2081]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01383.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3317]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01388.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1495      1.2867      1.2035]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01404.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0247      1.2729]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01414.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4169]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01425.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.277]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01430.png: ignoring corrupt image/label: negative label values [   -0.19998]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01440.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0842       1.123]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01450.png: ignoring corrupt image/label: negative label values [   -0.29846]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01479.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5172]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01485.png: ignoring corrupt image/label: negative label values [    -0.0016]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01504.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.699]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01519.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5326       1.224]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01529.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0444      1.7208        1.12      1.1581]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01537.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0353]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01552.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7919]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01572.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6433      1.4153]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01600.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3466      1.3324]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01615.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7715]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01620.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1616]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01625.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5708]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01644.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3647]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01664.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8647]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01706.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3981]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01716.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2731]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01746.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6435      1.2081]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01756.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3824]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01769.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3268]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01789.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2669]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01794.png: ignoring corrupt image/label: negative label values [   -0.13783  -0.0094945]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01819.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6889]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01821.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.9424]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01823.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1449]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01828.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5048      1.4578]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01842.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0753]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01862.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.123]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01872.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8602]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01877.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.238]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01882.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.603]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01892.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7913]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01897.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0301]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01916.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.67]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01959.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2281]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01969.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4932]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01974.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.078]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01984.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6847]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_01989.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1715]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02022.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.534      1.1945      1.3546]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02033.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4003      1.0095]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02038.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4101]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02043.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3637       1.119      1.4921]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02053.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4843      1.5685]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02079.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0979]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02109.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2952]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02130.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6166      1.3165]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02155.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3444      1.0353]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02160.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6576]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02167.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3389      1.2357      1.3954]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02177.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.9836      1.4277]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02182.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.9486]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02207.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2139      1.0559      1.0402      1.6535]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02217.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3194]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02227.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3401]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02232.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4421]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02237.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8186]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02242.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0405]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02247.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7152]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02262.png: ignoring corrupt image/label: negative label values [  -0.010986]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02267.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5671]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02300.png: ignoring corrupt image/label: negative label values [   -0.31277]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02308.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3547]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02318.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5196       1.221]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02323.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2784]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02333.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2696]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02354.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2551      1.5914]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02379.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2242]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02414.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0373]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02446.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3557]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02456.png: ignoring corrupt image/label: negative label values [   -0.34923]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02461.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.047]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02471.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3783]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02476.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2765]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02491.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4439]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02496.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1502]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02504.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4023      1.0515      1.2989]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02514.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2348]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02519.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5359]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02549.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0153]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02573.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1522]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02578.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3848]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02583.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8719]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02588.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0072      1.0563]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02619.png: ignoring corrupt image/label: negative label values [  -0.063522]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02636.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4967]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02661.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.8688]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02706.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6196      1.4815]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02721.png: ignoring corrupt image/label: negative label values [   -0.28589]
# train: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\train\images\screenshot_02726.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1
png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6879]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29903.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6641]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29906.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0149      1.2351]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29908.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2793]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29910.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3406]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29927.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1616       1.252]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29928.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2607      1.2992]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29932.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6918]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29941.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1431      1.0866]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29943.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1652       1.063]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29961.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2374      1.6139]
# val: C:\Users\fredr\BTH\Robotik Project\Robotics\YOLOv8-training\jetbot_groundview_dataset\val\images\screenshot_blur_29967.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0938      1.5493]
# Plotting labels to runs\train\jetbot_groundview\labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 4 dataloader workers
# Logging results to runs\train\jetbot_groundview
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.04G      1.823      2.968      1.927         72        512: 100%|██████████| 314/314 [01:53<00:00,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 46/46 [00:32<00:00,  1.40it/s]
#                    all       2943       3583      0.705      0.317      0.252      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.46G      1.545      2.429      1.649         73        512:  50%|█████     | 158/314 [00:23<00:19,  7.92it/s]

# %%
import os
from ultralytics import YOLO

# Path to your trained model
MODEL_PATH = "runs/train/jetbot_groundview/weights/best.pt"   # Update path if needed!
TRAIN_IMG_DIR = "jetbot_groundview_dataset/images/train"

# Load model
model = YOLO(MODEL_PATH)

# List all PNG images (ignoring 'debug')
image_files = [f for f in os.listdir(TRAIN_IMG_DIR) if f.endswith('.png') and 'debug' not in f]

print(f"Testing {len(image_files)} training images...")

for i, fname in enumerate(image_files):
    img_path = os.path.join(TRAIN_IMG_DIR, fname)
    results = model(img_path)
    
    print(f"\nImage: {fname}")
    for box, cls, conf in zip(results[0].boxes.xyxy, results[0].boxes.cls, results[0].boxes.conf):
        print(f"  - Class: {int(cls)}, Confidence: {conf:.2f}, Box: {box.cpu().numpy()}")
    
    # Show prediction
    results[0].show()   # Opens a window for each image (close to continue)

    # Optionally, to save annotated image to disk:
    results[0].save(filename=f"inference_train_{i}.png")

print("\nDone! Inspect visually and verify nearly perfect predictions on all training images.")
