# %%
import cv2
import numpy as np
import requests
from PIL import Image
import io

jetbot_ip = '194.47.156.22'


# Parametrar
KNOWN_WIDTH = 3.5  # iPhone bredd i cm
FOCAL_LENGTH = 500  # Byt till kalibrerat värde!

def get_jetbot_frame(jetbot_ip):
    response = requests.get(f'http://{jetbot_ip}:8080/camera')
    image = Image.open(io.BytesIO(response.content))
    frame = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    return frame

while True:
    try:
        frame = get_jetbot_frame(jetbot_ip)

        # LAB konvertering
        lab = cv2.cvtColor(frame, cv2.COLOR_BGR2LAB)
        L, A, B = cv2.split(lab)
        _, mask = cv2.threshold(A, 150, 255, cv2.THRESH_BINARY)

        kernel = np.ones((5,5), np.uint8)
        mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
        mask = cv2.morphologyEx(mask, cv2.MORPH_DILATE, kernel)

        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        for contour in contours:
            area = cv2.contourArea(contour)
            if area > 15:
                x, y, w, h = cv2.boundingRect(contour)
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 3)

                # Avståndsberäkning
                distance_cm = (KNOWN_WIDTH * FOCAL_LENGTH) / w
                cv2.putText(frame, f"Distance: {distance_cm:.2f} cm", (x, y - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2)

        # Visa
        cv2.imshow("Jetbot Red Object + Distance", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    except Exception as e:
        print(f"Error: {e}")

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37580/3132038266.py in <module>
#      20 while True:
#      21     try:
# ---> 22         frame = get_jetbot_frame(jetbot_ip)
#      23
#      24         # LAB konvertering
#
# ~\AppData\Local\Temp/ipykernel_37580/3132038266.py in get_jetbot_frame(jetbot_ip)
#      13
#      14 def get_jetbot_frame(jetbot_ip):
# ---> 15     response = requests.get(f'http://{jetbot_ip}:8080/camera')
#      16     image = Image.open(io.BytesIO(response.content))
#      17     frame = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
#
# c:\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# c:\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# c:\anaconda3\lib\site-packages\requests\models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# c:\anaconda3\lib\site-packages\requests\models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# c:\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# c:\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# c:\anaconda3\lib\http\client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# c:\anaconda3\lib\http\client.py in readinto(self, b)
#     505             # Ideally, we would raise IncompleteRead if the content-length
#     506             # wasn't satisfied, but it might break compatibility.
# --> 507             self._close_conn()
#     508         elif self.length is not None:
#     509             self.length -= n
#
# c:\anaconda3\lib\http\client.py in _close_conn(self)
#     411         fp = self.fp
#     412         self.fp = None
# --> 413         fp.close()
#     414
#     415     def close(self):
#
# c:\anaconda3\lib\socket.py in close(self)
#     737             return
#     738         io.RawIOBase.close(self)
# --> 739         self._sock._decref_socketios()
#     740         self._sock = None
#     741
#
# c:\anaconda3\lib\socket.py in _decref_socketios(self)
#     488             self._io_refs -= 1
#     489         if self._closed:
# --> 490             self.close()
#     491
#     492     def _real_close(self, _ss=_socket.socket):
#
# c:\anaconda3\lib\socket.py in close(self)
#     498         self._closed = True
#     499         if self._io_refs <= 0:
# --> 500             self._real_close()
#     501
#     502     def detach(self):
#
# c:\anaconda3\lib\socket.py in _real_close(self, _ss)
#     492     def _real_close(self, _ss=_socket.socket):
#     493         # This function should not reference any globals. See issue #808164.
# --> 494         _ss.close(self)
#     495
#     496     def close(self):
#
# KeyboardInterrupt:
